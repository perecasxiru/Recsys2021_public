# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster(dashboard_address=':8788')
client = Client(cluster)
client.restart()
# Out:
# <Client: 'tcp://127.0.0.1:44589' processes=6 threads=24, memory=125.60 GiB>

# %%
import dask.dataframe as dd
import numpy as np
import pandas as pd
import lightgbm as lgb
import gc

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.max_colwidth', 1000)

# %%
column_load_types = {'f01_num_hashtags': np.uint8, 'f02_AUTH_verified': 'category', 'f03_READ_verified': 'category',
                    'f04_auth_follows_read': 'category', 'f05_bert_length': np.uint16, 'f06_num_media': np.uint8,
                    'f07_num_domains': np.uint8, 'f08_ratio1': np.float32, 'f09_ratio2': np.float32, 
                    'f10_ratio3': np.float32, 'f11_ratio4': np.float32, 'f12_photo': np.uint8, 'f13_video': np.uint8,
                    'f14_GIF': np.uint8, 'f15_type': 'category', 'f16_hour': 'category', 'f17_num_links': np.uint8,
                    'f18_language': 'category', 'f19_weekday': 'category', 'f20_auth_creat_year': np.uint16, 
                    'f21_read_creat_year': np.uint16, 'f22_diff_creat_year':np.uint16}

# %%
column_type = {
    'bert': str, 'hashtags': str, 'tweet_id': str, 'media': str, 'links': str, 'domains': str, 'type': str, 'language': str, 'timestamp': np.uint32,
    'AUTH_user_id':str,'AUTH_follower_count':np.uint32,'AUTH_following_count':np.uint32,'AUTH_verified':bool,'AUTH_account_creation':np.uint32,
    'READ_user_id': str,'READ_follower_count':np.uint32,'READ_following_count':np.uint32,'READ_verified':bool,'READ_account_creation':np.uint32,
    'auth_follows_read': bool,
    'reply_timestamp':np.float32,'retweet_timestamp':np.float32,'quote_timestamp':np.float32,'like_timestamp':np.float32
}

# %%
from sklearn.metrics import log_loss, precision_recall_curve, auc


def calculate_ctr(gt):
    positive = len([x for x in gt if x == 1])
    ctr = positive / float(len(gt))
    return ctr


def compute_rce(pred, gt):
    cross_entropy = log_loss(gt, pred)
    data_ctr = calculate_ctr(gt)
    strawman_cross_entropy = log_loss(gt, [data_ctr for _ in range(len(gt))])
    return (1.0 - cross_entropy / strawman_cross_entropy) * 100.0


def compute_prauc_lgb(pred, g):
    gt = np.array(g.get_label())
    pred = np.array(pred)
    prec, recall, thresh = precision_recall_curve(gt, pred)
    prauc = auc(recall, prec)
    return 'prauc', prauc, True


def compute_rce_lgb(pred, g):
    gt = np.array(g.get_label())
    pred = np.array(pred)
    rce = compute_rce(pred, gt)
    return 'rce',rce,True


def focal_loss_lgb(y_pred, dtrain, alpha, gamma):
    a, g = alpha, gamma
    y_true = dtrain.label
    
    def fl(x,t):
        p = 1 / (1 + np.exp(-x))
        return -( a*t + (1-a)*(1-t) ) * (( 1 - ( t*p + (1-t)*(1-p)) )**g) * ( t*np.log(p)+(1-t)*np.log(1-p) )
    
    partial_fl = lambda x: fl(x, y_true)
    grad = derivative(partial_fl, y_pred, n=1, dx=1e-6)
    hess = derivative(partial_fl, y_pred, n=2, dx=1e-6)
    return grad, hess


def focal_loss_lgb_eval_error(y_pred, dtrain, alpha, gamma):
    a, g = alpha, gamma
    y_true = dtrain.label
    p = 1 / (1 + np.exp(-y_pred))
    loss = -( a*y_true + (1-a)*(1-y_true) ) * (( 1 - ( y_true*p + (1-y_true)*(1-p)) )**g) * ( y_true*np.log(p)+(1-y_true)*np.log(1-p) )
    return 'focal_loss', np.mean(loss), False

# %%
def basic_features(df):

    df['f01_num_hashtags'] = df.hashtags.str.split('\t').str.len().fillna(0).astype(np.uint8)
    df['f02_AUTH_verified'] = df.AUTH_verified.astype(int).astype('category')
    df['f03_READ_verified'] = df.READ_verified.astype(int).astype('category')
    df['f04_auth_follows_read'] = df.auth_follows_read.astype(int).astype('category')
    df['f05_bert_length'] = df.bert.str.split('\t').str.len().fillna(0).astype(np.uint16)
    #df = df.drop(columns=['bert'])
    df['f06_num_media'] = df.media.str.split('\t').str.len().fillna(0).astype(np.uint8)
    df['f07_num_domains'] = df.domains.str.split('\t').str.len().fillna(0).astype(np.uint8)
    df['f08_ratio1'] = df.AUTH_following_count/(df.READ_following_count+1e-6).astype(np.float32)
    df['f09_ratio2'] = df.AUTH_following_count/(df.READ_follower_count+1e-6).astype(np.float32)
    df['f10_ratio3'] = df.READ_following_count/(df.READ_follower_count+1e-6).astype(np.float32)
    df['f11_ratio4'] = df.AUTH_follower_count/(df.READ_follower_count+1e-6).astype(np.float32)
    df['f12_photo'] = df.media.str.count('Photo').fillna(0).astype(np.uint8)
    df['f13_video'] = df.media.str.count('Video').fillna(0).astype(np.uint8)
    df['f14_GIF'] = df.media.str.count('GIF').fillna(0).astype(np.uint8)
    df['f15_type'] = df.type.astype('category')
    df['f16_hour'] = df.timestamp.astype('M8[s]').dt.hour.astype('category')
    df['f17_num_links'] = df.links.str.split('\t').str.len().fillna(0).astype(np.uint8)

    dct_langs = {row['language']: i for i, row in pd.read_csv('/data/recsys/stats/language_counts.csv').iterrows() }
    df['f18_language'] = df.language.replace(dct_langs).astype('category')
    df['f19_weekday'] = df.timestamp.astype('M8[s]').dt.weekday.astype('category')
    df['f20_auth_creat_year'] = df.AUTH_account_creation.astype('M8[s]').dt.year.apply(lambda x: 0 if x<0 else x, meta=(None, 'int')).astype(np.uint16)
    df['f21_read_creat_year'] = df.READ_account_creation.astype('M8[s]').dt.year.apply(lambda x: 0 if x<0 else x, meta=(None, 'int')).astype(np.uint16)
    df['f22_diff_creat_year'] = (df.AUTH_account_creation.astype('M8[s]').dt.year.apply(lambda x: 0 if x<0 else x, meta=(None, 'int')).astype(int) - df.READ_account_creation.astype('M8[s]').dt.year.apply(lambda x: 0 if x<0 else x, meta=(None, 'int'))).astype(np.int16)    
    
    df['f23_at_bert'] = df.bert.str.contains('\t137\t').astype(np.uint8).astype('category')            # At sign: @
    df['f24_rt_at_bert'] = df.bert.str.contains('\t56898\t137\t').astype(np.uint8).astype('category')  # RT at sign: RT @
    
    df['f25_unk'] = df.bert.str.count('\t100\t').astype(np.uint8)
    df['f26_unk_ratio'] = (df['f25_unk'] / df['f05_bert_length']).astype(np.float32)

    return df


def text_features(df):
    df = pd.concat([df, df.bert.str.extract(r'^\d+\t(?P<f27_tok1>\d+)?\t(?P<f28_tok2>\d+)?\t.*\t(?P<f29_tok3>\d+)?\t(?P<f30_tok4>\d+)?\t\d+$').fillna(101)], axis=1)

    df['f27_tok1'] = pd.Categorical(df['f27_tok1'].astype(int), categories=list(range(0,119548)))
    df['f28_tok2'] = pd.Categorical(df['f28_tok2'].astype(int), categories=list(range(0,119548))) 
    df['f29_tok3'] = pd.Categorical(df['f29_tok3'].astype(int), categories=list(range(0,119548))) 
    df['f30_tok4'] = pd.Categorical(df['f30_tok4'].astype(int), categories=list(range(0,119548)))
    
    df['f31_question'] = df.bert.str.count('\t136\t').astype(np.uint8)
    return df


def merge_popularity(df):
    # AUTH popularity
    auth_merge = pd.read_csv('/data/recsys/auth_pop_tweet/auth_merge_div_counts.csv',
                             dtype={'reply': np.float32, 'retweet': np.float32, 
                                    'quote': np.float32, 'like': np.float32})
    auth_merge = auth_merge.rename(columns={'reply': 'avg_reply', 'retweet': 'avg_retweet', 
                                             'quote': 'avg_quote', 'like': 'avg_like'})
    df = df.reset_index(drop=True)

    _cols = ['avg_reply', 'avg_retweet', 'avg_quote', 'avg_like', 'AUTH_count_user_id']
    df[_cols] = pd.merge(df[['AUTH_user_id']], auth_merge, on='AUTH_user_id', how='left').fillna(0)[_cols]

    del auth_merge

    print('Auth done')

    # READ popularity
    read_merge = pd.read_csv('/data/recsys/read_pop/read_merge_div_counts.csv',
                             dtype={'reply': np.float32, 'retweet': np.float32, 
                                    'quote': np.float32, 'like': np.float32})
    read_merge = read_merge.rename(columns={'reply': 'avg_reply_read', 'retweet': 'avg_retweet_read', 
                                             'quote': 'avg_quote_read', 'like': 'avg_like_read'})
    df = df.reset_index(drop=True)
    _cols = ['avg_reply_read', 'avg_retweet_read', 'avg_quote_read', 'avg_like_read', 'READ_count_user_id']
    df[_cols] = pd.merge(df[['READ_user_id']], read_merge, on='READ_user_id', how='left').fillna(0)[_cols]
    
    del read_merge, _cols
    
    print('Read done')

    return df


def merge_type_pop(df):

    auth_merge = pd.read_csv('/data/recsys/tef_auth_tt/auth_tt_merge_div.csv').rename(columns = {'is_cT':'is_aT', 'is_cR':'is_aR', 'is_cQ':'is_aQ'})
    df = df.reset_index(drop=True)
    _cols = ['rep_aT', 'ret_aT', 'quo_aT', 'lik_aT', 'rep_aR', 'ret_aR', 'quo_aR', 'lik_aR', 'rep_aQ', 'ret_aQ', 'quo_aQ', 'lik_aQ', 'is_aT', 'is_aR', 'is_aQ']
    df[_cols] = pd.merge(df[['AUTH_user_id']], auth_merge, on='AUTH_user_id', how='left').fillna(0)[_cols]
    del auth_merge, _cols
    print("Auth type done")

    read_merge = pd.read_csv('/data/recsys/tef_read_tt/read_tt_merge_div.csv').rename(columns = {'is_cT': 'is_aT', 'is_cR': 'is_aR', 'is_cQ': 'is_aQ'})
    _cols_old = ['rep_aT', 'ret_aT', 'quo_aT', 'lik_aT', 'rep_aR', 'ret_aR', 'quo_aR', 'lik_aR', 'rep_aQ', 'ret_aQ', 'quo_aQ', 'lik_aQ', 'is_aT', 'is_aR', 'is_aQ']
    _cols = [c+'_read' for c in _cols_old]
    read_merge = read_merge.rename(columns=dict(zip(_cols_old, _cols)))
    df = df.reset_index(drop=True)
    df[_cols] = pd.merge(df[['READ_user_id']], read_merge, on='READ_user_id', how='left').fillna(0)[_cols]
    del read_merge, _cols_old, _cols

    print('Read type done')
    return df


def smooth_pops(dfd):
    _means = json.load(open('means.json', 'r'))

    K=10

    for prob in ['avg_reply', 'avg_retweet', 'avg_quote', 'avg_like', 
            'avg_reply_read', 'avg_retweet_read', 'avg_quote_read', 'avg_like_read',
            'rep_aT', 'ret_aT', 'quo_aT', 'lik_aT', 'rep_aR', 'ret_aR', 'quo_aR', 'lik_aR', 'rep_aQ', 'ret_aQ', 'quo_aQ', 'lik_aQ',
            'rep_aT_read', 'ret_aT_read', 'quo_aT_read', 'lik_aT_read', 'rep_aR_read', 'ret_aR_read', 'quo_aR_read', 'lik_aR_read', 'rep_aQ_read', 'ret_aQ_read', 'quo_aQ_read', 'lik_aQ_read']:
    
        dfd['a_count'] = dfd['is_aT']+dfd['is_aR']+dfd['is_aQ']
        dfd['r_count'] = dfd['is_aT_read'] + dfd['is_aR_read'] + dfd['is_aQ_read']
    
        if 'lik' in prob:
            mn = _means['like']
        if 'ret' in prob:
            mn = _means['retweet']
        if 'quo' in prob:
            mn = _means['quote']
        if 'rep' in prob:
            mn = _means['reply']
    
        if 'avg' in prob:
            if 'read' in prob:
                dfd[prob] = ((dfd[prob] * dfd['r_count']) + (mn * K)) / (K + dfd['r_count'])
            else:
                dfd[prob] = ((dfd[prob] * dfd['a_count']) + (mn * K)) / (K + dfd['a_count'])    
        else:
            if 'aT' in prob:
                if 'read' in prob:
                    dfd[prob] = ((dfd[prob] * dfd['is_aT_read']) + (mn * K)) / (K + dfd['is_aT_read'])
                else:
                    dfd[prob] = ((dfd[prob] * dfd['is_aT']) + (mn * K)) / (K + dfd['is_aT'])
            
            elif 'aR' in prob:
                if 'read' in prob:
                    dfd[prob] = ((dfd[prob] * dfd['is_aR_read']) + (mn * K)) / (K + dfd['is_aR_read'])
                else:
                    dfd[prob] = ((dfd[prob] * dfd['is_aR']) + (mn * K)) / (K + dfd['is_aR'])
            
            else:
                if 'read' in prob:
                    dfd[prob] = ((dfd[prob] * dfd['is_aQ_read']) + (mn * K)) / (K + dfd['is_aQ_read'])
                else:
                    dfd[prob] = ((dfd[prob] * dfd['is_aQ']) + (mn * K)) / (K + dfd['is_aQ'])

    return dfd


df = dd.read_csv('/data/recsys/valid/part-00000.1', names=list(column_type.keys()), header=None, sep='\x01', dtype=column_type)    

# Create basic features and save its names
df = basic_features(df)
features = ['AUTH_follower_count', 'AUTH_following_count', 'READ_follower_count', 'READ_following_count']
features = features + [col for col in df.columns if col[1:3] in [f'{i:02d}' for i in range(1, 100)]]

# Compute the dataset. Merges and concats with dask can bring problems
df = df.loc[:, ['bert','tweet_id', 'AUTH_user_id', 'READ_user_id','like_timestamp','retweet_timestamp','quote_timestamp','reply_timestamp']+features].compute()

# Text features
df = text_features(df)

features = ['AUTH_follower_count', 'AUTH_following_count', 'READ_follower_count', 'READ_following_count']
features = features + sorted([col for col in df.columns if col[1:3] in [f'{i:02d}' for i in range(1, 100)]])

# Compute logcounts appearances log10(appearances)
# df = merge_logcounts(df)
# features = features + ['f25_auth_log_count', 'f26_read_log_count']

print('Compute completed')

# Merge the popularity as 8 new columns
df = merge_popularity(df)
features = features + ['avg_reply', 'avg_retweet', 'avg_quote', 'avg_like']
features = features + ['avg_reply_read', 'avg_retweet_read', 'avg_quote_read', 'avg_like_read']

df = merge_type_pop(df)
tp = ['rep_aT', 'ret_aT', 'quo_aT', 'lik_aT', 'rep_aR', 'ret_aR', 'quo_aR', 'lik_aR', 'rep_aQ', 'ret_aQ', 'quo_aQ', 'lik_aQ']
features = features + tp
features = features + [t+'_read' for t in tp]
features = features + ['a_count', 'r_count']

for target in ['like', 'retweet', 'reply', 'quote']:
    df[target + '_timestamp'] = (df[target + '_timestamp'] > 0).astype(np.uint8)

import json
df = smooth_pops(df)
# Out:
# Compute completed
# Auth done
# Read done
# Auth type done
# Read type done

# %%
df = df[df['a_count'] < 5]

# %%
dfd = pd.concat([pd.read_csv('/data/recsys/sample_coldstart_auth.csv'),
                 pd.read_csv('/data/recsys/sample_coldstart_auth_V1.csv'),
                 pd.read_csv('/data/recsys/sample_coldstart_auth_V2.csv'),
                 pd.read_csv('/data/recsys/sample_coldstart_auth_V3.csv'),
                 pd.read_csv('/data/recsys/sample_coldstart_auth_V4.csv'),
                 pd.read_csv('/data/recsys/sample_coldstart_auth_V5.csv')])

# %%
dfd['f02_AUTH_verified'] = pd.Categorical(dfd['f02_AUTH_verified'].astype(int), categories=list(range(0, 2)))
dfd['f03_READ_verified'] = pd.Categorical(dfd['f03_READ_verified'].astype(int), categories=list(range(0, 2)))
dfd['f04_auth_follows_read'] = pd.Categorical(dfd['f04_auth_follows_read'].astype(int), categories=list(range(0, 2)))
dfd['f15_type'] = pd.Categorical(dfd['f15_type'].astype(str), categories=["Quote", "Retweet", "TopLevel"])
dfd['f16_hour'] = pd.Categorical(dfd['f16_hour'].astype(int), categories=list(range(0, 24)))
dfd['f18_language'] = pd.Categorical(dfd['f18_language'].astype(int), categories=list(range(0, 66)))
dfd['f19_weekday'] = pd.Categorical(dfd['f19_weekday'].astype(int), categories=[3, 4, 5, 6, 0, 1, 2])

dfd['f23_at_bert'] = pd.Categorical(dfd['f23_at_bert'].astype(int), categories=list(range(0, 2)))
dfd['f24_rt_at_bert'] = pd.Categorical(dfd['f24_rt_at_bert'].astype(int), categories=list(range(0, 2)))

dfd['f27_tok1'] = pd.Categorical(dfd['f27_tok1'].astype(int), categories=list(range(0, 119548)))
dfd['f28_tok2'] = pd.Categorical(dfd['f28_tok2'].astype(int), categories=list(range(0, 119548))) 
dfd['f29_tok3'] = pd.Categorical(dfd['f29_tok3'].astype(int), categories=list(range(0, 119548))) 
dfd['f30_tok4'] = pd.Categorical(dfd['f30_tok4'].astype(int), categories=list(range(0, 119548)))

for target in ['like', 'retweet', 'reply', 'quote']:
    dfd[target + '_timestamp'] = (dfd[target + '_timestamp'] > 0).astype(np.uint8)

# %%
dfd['a_count'] = dfd['is_aT']+dfd['is_aR']+dfd['is_aQ']
dfd['r_count'] = dfd['is_aT_read'] + dfd['is_aR_read'] + dfd['is_aQ_read']

# %%
nf = features + [target + '_timestamp' for target in ['like', 'retweet', 'reply', 'quote']]
df = pd.concat([dfd[nf], df[nf]])

# %%
from sklearn.model_selection import train_test_split

# %%
to_remove = ['avg_reply', 'avg_retweet', 'avg_quote', 'avg_like'] + ['rep_aT', 'ret_aT', 'quo_aT', 'lik_aT', 'rep_aR', 'ret_aR', 'quo_aR', 'lik_aR', 'rep_aQ', 'ret_aQ', 'quo_aQ', 'lik_aQ']
df = df.drop(columns=to_remove)

# %%
for t in to_remove:
    features.remove(t)

# %%
print(features)
display(df.head())
# Out:
# ['AUTH_follower_count', 'AUTH_following_count', 'READ_follower_count', 'READ_following_count', 'f01_num_hashtags', 'f02_AUTH_verified', 'f03_READ_verified', 'f04_auth_follows_read', 'f05_bert_length', 'f06_num_media', 'f07_num_domains', 'f08_ratio1', 'f09_ratio2', 'f10_ratio3', 'f11_ratio4', 'f12_photo', 'f13_video', 'f14_GIF', 'f15_type', 'f16_hour', 'f17_num_links', 'f18_language', 'f19_weekday', 'f20_auth_creat_year', 'f21_read_creat_year', 'f22_diff_creat_year', 'f23_at_bert', 'f24_rt_at_bert', 'f25_unk', 'f26_unk_ratio', 'f27_tok1', 'f28_tok2', 'f29_tok3', 'f30_tok4', 'f31_question', 'avg_reply_read', 'avg_retweet_read', 'avg_quote_read', 'avg_like_read', 'rep_aT_read', 'ret_aT_read', 'quo_aT_read', 'lik_aT_read', 'rep_aR_read', 'ret_aR_read', 'quo_aR_read', 'lik_aR_read', 'rep_aQ_read', 'ret_aQ_read', 'quo_aQ_read', 'lik_aQ_read', 'a_count', 'r_count']
#    AUTH_follower_count  AUTH_following_count  READ_follower_count  \
# 0                  153                   233                  442
# 1                   53                    54                   31
# 2                   53                   420                 3022
# 3                   93                    80                 3574
# 4                   14                    13                  169
#
#    READ_following_count  f01_num_hashtags f02_AUTH_verified f03_READ_verified  \
# 0                  1112                 1                 0                 0
# 1                    51                 2                 0                 0
# 2                  2316                 0                 0                 0
# 3                   232                 0                 0                 0
# 4                   110                 0                 0                 0
#
#   f04_auth_follows_read  f05_bert_length  f06_num_media  f07_num_domains  \
# 0                     1               56              1                0
# 1                     1               57              4                0
# 2                     1               41              0                0
# 3                     0               54              0                0
# 4                     1               15              1                0
#
#    f08_ratio1  f09_ratio2  f10_ratio3  f11_ratio4  f12_photo  f13_video  \
# 0    0.209532    0.527149    2.515837    0.346154          1          0
# 1    1.058824    1.741935    1.645161    1.709677          4          0
# 2    0.181347    0.138981    0.766380    0.017538          0          0
# 3    0.344828    0.022384    0.064913    0.026021          0          0
# 4    0.118182    0.076923    0.650888    0.082840          0          1
#
#    f14_GIF  f15_type f16_hour  f17_num_links f18_language f19_weekday  \
# 0        0  TopLevel       15              0            1           0
# 1        0  TopLevel        8              0            0           1
# 2        0   Retweet       16              0            2           0
# 3        0   Retweet        8              0           11           2
# 4        0  TopLevel        1              0            4           0
#
#    f20_auth_creat_year  f21_read_creat_year  f22_diff_creat_year  f23_at_bert  \
# 0                 2020                 2013                    7          0.0
# 1                 2020                 2020                    0          0.0
# 2                 2017                 2010                    7          1.0
# 3                 2020                 2017                    3          1.0
# 4                 2020                 2019                    1          0.0
#
#    f24_rt_at_bert  f25_unk  f26_unk_ratio f27_tok1 f28_tok2 f29_tok3 f30_tok4  \
# 0             0.0        1       0.017857     5318     4321    13966    11211
# 1             0.0        0       0.000000    19425    12047    19282    12396
# 2             1.0        1       0.024390    56898      137    16348      100
# 3             1.0        1       0.018519    56898      137      860      100
# 4             0.0        0       0.000000    14120      131    47799    11396
#
#    f31_question  avg_reply_read  avg_retweet_read  avg_quote_read  \
# 0             0        0.000000          0.000000             0.0
# 1             0        0.000000          0.200000             0.0
# 2             0        0.108108          0.027027             0.0
# 3             0        0.000000          0.000000             0.0
# 4             0        0.023256          0.069767             0.0
#
#    avg_like_read  rep_aT_read  ret_aT_read  quo_aT_read  lik_aT_read  \
# 0       0.433790      0.00000      0.00000          0.0       0.4058
# 1       0.400000      0.00000      0.00000          0.0       0.4000
# 2       0.378378      0.12500      0.00000          0.0       0.5625
# 3       0.000000      0.00000      0.00000          0.0       0.0000
# 4       0.465116      0.03125      0.09375          0.0       0.5938
#
#    rep_aR_read  ret_aR_read  quo_aR_read  lik_aR_read  rep_aQ_read  \
# 0          0.0       0.0000          0.0       0.4614          0.0
# 1          0.0       0.4285          0.0       0.4285          0.0
# 2          0.0       0.0909          0.0       0.0909          0.2
# 3          0.0       0.0000          0.0       0.0000          0.0
# 4          0.0       0.0000          0.0       0.1000          0.0
#
#    ret_aQ_read  quo_aQ_read  lik_aQ_read  a_count  r_count  like_timestamp  \
# 0          0.0          0.0       0.4443      0.0    219.0               1
# 1          0.0          0.0       0.3333      3.0     15.0               1
# 2          0.0          0.0       0.4000      0.0     37.0               0
# 3          0.0          0.0       0.0000      1.0      3.0               0
# 4          0.0          0.0       0.0000      1.0     43.0               1
#
#    retweet_timestamp  reply_timestamp  quote_timestamp
# 0                  0                0                0
# 1                  0                0                0
# 2                  0                0                0
# 3                  1                0                0
# 4                  0                0                0

# %%
# %%time

### TESTING

#27.8, 31.8, 31.1, 22.5

# Set it to True to predict the next engagements using the predictions from the previous ones
chained_prediction = True

boosters = []

for target in ['like', 'retweet', 'reply', 'quote']:
    
    df_train, df_test = train_test_split(df, stratify=df[f'{target}_timestamp'], test_size=0.2)
    train_data = lgb.Dataset(df_train.loc[:, features], label=df_train[f'{target}_timestamp'])
    test_data = lgb.Dataset(df_test.loc[:, features], label=df_test[f'{target}_timestamp'])
    
    _, df_train_sample = train_test_split(df_train, stratify=df_train[f'{target}_timestamp'], test_size=int(1e5))
    train_data_sample = lgb.Dataset(df_train_sample.loc[:, features], label=df_train_sample[f'{target}_timestamp'])
    
    # https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.train.html#lightgbm.train
    param = {'max_depth': 10,
             'nthread': 24,
             'num_leaves': 128,
             'lambda_l1': 1,
             'lambda_l2': 1,
             'bagging_freq':1,        # Always perform bagging
             'bagging_fraction':0.66, # % of rows selected in each tree
             #'min_data_in_leaf':1000,
             #'min_gain_to_split':0.01,
             'feature_fraction':0.8,
#                  'boosting':'dart',
             'learning_rate': 0.01,
             'objective':'cross_entropy',
             'metric': 'None',   # For the null metric use 'None' instead of None:
                                 #  None  -> objective metric is considered in early stopping
                                 # 'None' -> objective is not considered
             'device': 'cpu',
             'random_state': 42,
             'is_unbalance': True}

    print(target)
    print('=' * 50)

    evals_result = {}
    alpha = 0.1
    k = -0.004
    lgb_model = lgb.train(param,
                          train_data,
                          num_boost_round=5000,
                          evals_result=evals_result,
                                                                           # function vs metric:
                                                                           # function: custom defined (callable)
                                                                           # metric: predefined string
                          feval=[compute_rce_lgb, compute_prauc_lgb],      # To use feval you must set metric to None
                          valid_sets=[train_data_sample, test_data],
#                           early_stopping_rounds=25,
                              callbacks=[
                                      # First metric only to use only RCE for early stopping
                                      # since it is the one with higher impact
                                      lgb.early_stopping(50, first_metric_only=True),
                                      lgb.reset_parameter(learning_rate=lambda current_round: alpha * np.exp(k * current_round))
                              ],
                          verbose_eval=25)
    lgb_model.save_model(f'{target}_bst.lgb')
    boosters.append((lgb_model, evals_result))
    print()
    print()

    # OPTIONAL: Predicted label as feature for next
    if chained_prediction:
        df[target + '_timestamp'] = lgb_model.predict(df.loc[:, features])
        features += [target + '_timestamp']
# Out:
# like
# ==================================================
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.178827 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 27245
# [LightGBM] [Info] Number of data points in the train set: 3607787, number of used features: 53
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.319685 -> initscore = -0.755219
# [LightGBM] [Info] Start training from score -0.755219
# Training until validation scores don't improve for 50 rounds
# [25]	valid_0's rce: 16.5432	valid_0's prauc: 0.609808	valid_1's rce: 16.0748	valid_1's prauc: 0.599548
# [50]	valid_0's rce: 18.553	valid_0's prauc: 0.628859	valid_1's rce: 17.3764	valid_1's prauc: 0.607792
# [75]	valid_0's rce: 19.4121	valid_0's prauc: 0.637751	valid_1's rce: 17.7984	valid_1's prauc: 0.610855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's rce: 19.7385	valid_0's prauc: 0.641589	valid_1's rce: 17.9155	valid_1's prauc: 0.611654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's rce: 19.9461	valid_0's prauc: 0.64387	valid_1's rce: 17.9875	valid_1's prauc: 0.612178
# [150]	valid_0's rce: 20.1015	valid_0's prauc: 0.645457	valid_1's rce: 18.029	valid_1's prauc: 0.612494
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's rce: 20.2256	valid_0's prauc: 0.646916	valid_1's rce: 18.0574	valid_1's prauc: 0.612653
# [200]	valid_0's rce: 20.3155	valid_0's prauc: 0.648038	valid_1's rce: 18.0691	valid_1's prauc: 0.612709
# [225]	valid_0's rce: 20.3961	valid_0's prauc: 0.649041	valid_1's rce: 18.0835	valid_1's prauc: 0.612771
# [250]	valid_0's rce: 20.4622	valid_0's prauc: 0.649773	valid_1's rce: 18.0918	valid_1's prauc: 0.612761
# [275]	valid_0's rce: 20.526	valid_0's prauc: 0.650526	valid_1's rce: 18.1003	valid_1's prauc: 0.612769
# [300]	valid_0's rce: 20.5753	valid_0's prauc: 0.651195	valid_1's rce: 18.1021	valid_1's prauc: 0.612731
# [325]	valid_0's rce: 20.6312	valid_0's prauc: 0.651858	valid_1's rce: 18.1204	valid_1's prauc: 0.612887
# [350]	valid_0's rce: 20.67	valid_0's prauc: 0.652366	valid_1's rce: 18.1228	valid_1's prauc: 0.612871
# [375]	valid_0's rce: 20.7099	valid_0's prauc: 0.652814	valid_1's rce: 18.1297	valid_1's prauc: 0.612888
# [400]	valid_0's rce: 20.7421	valid_0's prauc: 0.653227	valid_1's rce: 18.1317	valid_1's prauc: 0.612885
# [425]	valid_0's rce: 20.7749	valid_0's prauc: 0.65359	valid_1's rce: 18.1355	valid_1's prauc: 0.612898
# [450]	valid_0's rce: 20.7987	valid_0's prauc: 0.653867	valid_1's rce: 18.1368	valid_1's prauc: 0.612898
# [475]	valid_0's rce: 20.8231	valid_0's prauc: 0.654204	valid_1's rce: 18.1381	valid_1's prauc: 0.612903
# [500]	valid_0's rce: 20.8463	valid_0's prauc: 0.654482	valid_1's rce: 18.1409	valid_1's prauc: 0.612903
# [525]	valid_0's rce: 20.8691	valid_0's prauc: 0.654755	valid_1's rce: 18.1451	valid_1's prauc: 0.612921
# [550]	valid_0's rce: 20.8879	valid_0's prauc: 0.655002	valid_1's rce: 18.1473	valid_1's prauc: 0.612934
# [575]	valid_0's rce: 20.9068	valid_0's prauc: 0.655262	valid_1's rce: 18.1501	valid_1's prauc: 0.612959
# [600]	valid_0's rce: 20.9235	valid_0's prauc: 0.655442	valid_1's rce: 18.154	valid_1's prauc: 0.612988
# [625]	valid_0's rce: 20.9356	valid_0's prauc: 0.6556	valid_1's rce: 18.1547	valid_1's prauc: 0.612984
# [650]	valid_0's rce: 20.9458	valid_0's prauc: 0.65573	valid_1's rce: 18.1552	valid_1's prauc: 0.612977
# [675]	valid_0's rce: 20.9554	valid_0's prauc: 0.655849	valid_1's rce: 18.1557	valid_1's prauc: 0.612969
# [700]	valid_0's rce: 20.9659	valid_0's prauc: 0.655974	valid_1's rce: 18.158	valid_1's prauc: 0.612985
# [725]	valid_0's rce: 20.9735	valid_0's prauc: 0.656073	valid_1's rce: 18.1586	valid_1's prauc: 0.612986
# [750]	valid_0's rce: 20.9805	valid_0's prauc: 0.656156	valid_1's rce: 18.1592	valid_1's prauc: 0.612989
# [775]	valid_0's rce: 20.9868	valid_0's prauc: 0.656228	valid_1's rce: 18.1592	valid_1's prauc: 0.612984
# [800]	valid_0's rce: 20.992	valid_0's prauc: 0.656294	valid_1's rce: 18.1593	valid_1's prauc: 0.612979
# Early stopping, best iteration is:
# [761]	valid_0's rce: 20.9836	valid_0's prauc: 0.656192	valid_1's rce: 18.1594	valid_1's prauc: 0.612989
# Evaluated only: rce
#
#
# retweet
# ==================================================
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.163955 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 27507
# [LightGBM] [Info] Number of data points in the train set: 3607787, number of used features: 54
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.057834 -> initscore = -2.790598
# [LightGBM] [Info] Start training from score -2.790598
# Training until validation scores don't improve for 50 rounds
# [25]	valid_0's rce: 16.1504	valid_0's prauc: 0.2476	valid_1's rce: 13.9404	valid_1's prauc: 0.21617
# [50]	valid_0's rce: 18.511	valid_0's prauc: 0.271988	valid_1's rce: 14.9453	valid_1's prauc: 0.222619
# [75]	valid_0's rce: 19.3791	valid_0's prauc: 0.283681	valid_1's rce: 15.163	valid_1's prauc: 0.22405
# [100]	valid_0's rce: 19.8326	valid_0's prauc: 0.290569	valid_1's rce: 15.2386	valid_1's prauc: 0.224548
# [125]	valid_0's rce: 20.2194	valid_0's prauc: 0.295883	valid_1's rce: 15.3011	valid_1's prauc: 0.224844
# [150]	valid_0's rce: 20.531	valid_0's prauc: 0.300632	valid_1's rce: 15.3323	valid_1's prauc: 0.225065
# [175]	valid_0's rce: 20.7937	valid_0's prauc: 0.304679	valid_1's rce: 15.351	valid_1's prauc: 0.225309
# [200]	valid_0's rce: 21.0432	valid_0's prauc: 0.308332	valid_1's rce: 15.3829	valid_1's prauc: 0.225617
# [225]	valid_0's rce: 21.2447	valid_0's prauc: 0.311534	valid_1's rce: 15.3937	valid_1's prauc: 0.225797
# [250]	valid_0's rce: 21.4263	valid_0's prauc: 0.314435	valid_1's rce: 15.396	valid_1's prauc: 0.225776
# [275]	valid_0's rce: 21.5872	valid_0's prauc: 0.31698	valid_1's rce: 15.4074	valid_1's prauc: 0.225923
# [300]	valid_0's rce: 21.7268	valid_0's prauc: 0.319276	valid_1's rce: 15.4115	valid_1's prauc: 0.22602
# [325]	valid_0's rce: 21.8607	valid_0's prauc: 0.321473	valid_1's rce: 15.4251	valid_1's prauc: 0.226231
# [350]	valid_0's rce: 21.97	valid_0's prauc: 0.323315	valid_1's rce: 15.4297	valid_1's prauc: 0.226278
# [375]	valid_0's rce: 22.073	valid_0's prauc: 0.325157	valid_1's rce: 15.4333	valid_1's prauc: 0.226346
# [400]	valid_0's rce: 22.1671	valid_0's prauc: 0.326816	valid_1's rce: 15.4444	valid_1's prauc: 0.226513
# [425]	valid_0's rce: 22.2478	valid_0's prauc: 0.328211	valid_1's rce: 15.4492	valid_1's prauc: 0.226585
# [450]	valid_0's rce: 22.3243	valid_0's prauc: 0.32942	valid_1's rce: 15.4521	valid_1's prauc: 0.226663
# [475]	valid_0's rce: 22.383	valid_0's prauc: 0.33054	valid_1's rce: 15.4543	valid_1's prauc: 0.226706
# [500]	valid_0's rce: 22.4452	valid_0's prauc: 0.331633	valid_1's rce: 15.4588	valid_1's prauc: 0.226793
# [525]	valid_0's rce: 22.499	valid_0's prauc: 0.332668	valid_1's rce: 15.4629	valid_1's prauc: 0.226863
# [550]	valid_0's rce: 22.5454	valid_0's prauc: 0.333473	valid_1's rce: 15.468	valid_1's prauc: 0.226931
# [575]	valid_0's rce: 22.5829	valid_0's prauc: 0.334153	valid_1's rce: 15.4707	valid_1's prauc: 0.22699
# [600]	valid_0's rce: 22.6254	valid_0's prauc: 0.334917	valid_1's rce: 15.4753	valid_1's prauc: 0.227057
# [625]	valid_0's rce: 22.6594	valid_0's prauc: 0.335482	valid_1's rce: 15.4774	valid_1's prauc: 0.227097
# [650]	valid_0's rce: 22.6925	valid_0's prauc: 0.336004	valid_1's rce: 15.4796	valid_1's prauc: 0.227142
# [675]	valid_0's rce: 22.7256	valid_0's prauc: 0.336621	valid_1's rce: 15.4829	valid_1's prauc: 0.227191
# [700]	valid_0's rce: 22.7497	valid_0's prauc: 0.337071	valid_1's rce: 15.4853	valid_1's prauc: 0.227225
# [725]	valid_0's rce: 22.7719	valid_0's prauc: 0.33743	valid_1's rce: 15.4865	valid_1's prauc: 0.227255
# [750]	valid_0's rce: 22.7926	valid_0's prauc: 0.337774	valid_1's rce: 15.488	valid_1's prauc: 0.227286
# [775]	valid_0's rce: 22.8101	valid_0's prauc: 0.338066	valid_1's rce: 15.4891	valid_1's prauc: 0.227314
# [800]	valid_0's rce: 22.8276	valid_0's prauc: 0.338391	valid_1's rce: 15.4903	valid_1's prauc: 0.227339
# [825]	valid_0's rce: 22.8429	valid_0's prauc: 0.338661	valid_1's rce: 15.4914	valid_1's prauc: 0.227353
# [850]	valid_0's rce: 22.8575	valid_0's prauc: 0.33893	valid_1's rce: 15.4921	valid_1's prauc: 0.227369
# [875]	valid_0's rce: 22.8719	valid_0's prauc: 0.339166	valid_1's rce: 15.4943	valid_1's prauc: 0.227405
# [900]	valid_0's rce: 22.8844	valid_0's prauc: 0.339385	valid_1's rce: 15.4954	valid_1's prauc: 0.227426
# [925]	valid_0's rce: 22.8936	valid_0's prauc: 0.339555	valid_1's rce: 15.4963	valid_1's prauc: 0.227441
# [950]	valid_0's rce: 22.9039	valid_0's prauc: 0.339736	valid_1's rce: 15.497	valid_1's prauc: 0.227453
# [975]	valid_0's rce: 22.9121	valid_0's prauc: 0.339894	valid_1's rce: 15.4977	valid_1's prauc: 0.227467
# [1000]	valid_0's rce: 22.9202	valid_0's prauc: 0.340038	valid_1's rce: 15.4983	valid_1's prauc: 0.227477
# [1025]	valid_0's rce: 22.9277	valid_0's prauc: 0.340182	valid_1's rce: 15.499	valid_1's prauc: 0.22749
# [1050]	valid_0's rce: 22.934	valid_0's prauc: 0.340291	valid_1's rce: 15.4995	valid_1's prauc: 0.227497
# [1075]	valid_0's rce: 22.9396	valid_0's prauc: 0.340382	valid_1's rce: 15.5	valid_1's prauc: 0.227506
# [1100]	valid_0's rce: 22.9443	valid_0's prauc: 0.340459	valid_1's rce: 15.5003	valid_1's prauc: 0.227515
# [1125]	valid_0's rce: 22.9487	valid_0's prauc: 0.34054	valid_1's rce: 15.5008	valid_1's prauc: 0.22752
# [1150]	valid_0's rce: 22.9531	valid_0's prauc: 0.340615	valid_1's rce: 15.501	valid_1's prauc: 0.227526
# [1175]	valid_0's rce: 22.9569	valid_0's prauc: 0.340682	valid_1's rce: 15.5013	valid_1's prauc: 0.227532
# [1200]	valid_0's rce: 22.9603	valid_0's prauc: 0.340751	valid_1's rce: 15.5016	valid_1's prauc: 0.22754
# [1225]	valid_0's rce: 22.9636	valid_0's prauc: 0.340808	valid_1's rce: 15.5019	valid_1's prauc: 0.227544
# [1250]	valid_0's rce: 22.9666	valid_0's prauc: 0.34087	valid_1's rce: 15.502	valid_1's prauc: 0.227547
# [1275]	valid_0's rce: 22.9693	valid_0's prauc: 0.340918	valid_1's rce: 15.5022	valid_1's prauc: 0.22755
# [1300]	valid_0's rce: 22.9714	valid_0's prauc: 0.340957	valid_1's rce: 15.5026	valid_1's prauc: 0.227557
# [1325]	valid_0's rce: 22.9733	valid_0's prauc: 0.34099	valid_1's rce: 15.5027	valid_1's prauc: 0.227559
# [1350]	valid_0's rce: 22.9751	valid_0's prauc: 0.341018	valid_1's rce: 15.5028	valid_1's prauc: 0.227561
# [1375]	valid_0's rce: 22.9769	valid_0's prauc: 0.341055	valid_1's rce: 15.503	valid_1's prauc: 0.227564
# [1400]	valid_0's rce: 22.9785	valid_0's prauc: 0.341085	valid_1's rce: 15.5031	valid_1's prauc: 0.227566
# [1425]	valid_0's rce: 22.9801	valid_0's prauc: 0.341114	valid_1's rce: 15.5033	valid_1's prauc: 0.227569
# [1450]	valid_0's rce: 22.9814	valid_0's prauc: 0.341139	valid_1's rce: 15.5034	valid_1's prauc: 0.22757
# [1475]	valid_0's rce: 22.9825	valid_0's prauc: 0.341156	valid_1's rce: 15.5034	valid_1's prauc: 0.227571
# [1500]	valid_0's rce: 22.9835	valid_0's prauc: 0.341173	valid_1's rce: 15.5035	valid_1's prauc: 0.227572
# [1525]	valid_0's rce: 22.9844	valid_0's prauc: 0.341186	valid_1's rce: 15.5036	valid_1's prauc: 0.227573
# [1550]	valid_0's rce: 22.9852	valid_0's prauc: 0.341203	valid_1's rce: 15.5036	valid_1's prauc: 0.227575
# [1575]	valid_0's rce: 22.986	valid_0's prauc: 0.341216	valid_1's rce: 15.5037	valid_1's prauc: 0.227576
# [1600]	valid_0's rce: 22.9868	valid_0's prauc: 0.34123	valid_1's rce: 15.5038	valid_1's prauc: 0.227578
# [1625]	valid_0's rce: 22.9875	valid_0's prauc: 0.341242	valid_1's rce: 15.5039	valid_1's prauc: 0.227579
# [1650]	valid_0's rce: 22.988	valid_0's prauc: 0.341255	valid_1's rce: 15.504	valid_1's prauc: 0.22758
# [1675]	valid_0's rce: 22.9885	valid_0's prauc: 0.341264	valid_1's rce: 15.504	valid_1's prauc: 0.227581
# [1700]	valid_0's rce: 22.989	valid_0's prauc: 0.341273	valid_1's rce: 15.504	valid_1's prauc: 0.227581
# [1725]	valid_0's rce: 22.9894	valid_0's prauc: 0.341277	valid_1's rce: 15.5041	valid_1's prauc: 0.227582
# [1750]	valid_0's rce: 22.9898	valid_0's prauc: 0.341285	valid_1's rce: 15.5041	valid_1's prauc: 0.227583
# [1775]	valid_0's rce: 22.9901	valid_0's prauc: 0.34129	valid_1's rce: 15.5041	valid_1's prauc: 0.227583
# [1800]	valid_0's rce: 22.9904	valid_0's prauc: 0.341296	valid_1's rce: 15.5042	valid_1's prauc: 0.227584
# [1825]	valid_0's rce: 22.9907	valid_0's prauc: 0.341302	valid_1's rce: 15.5042	valid_1's prauc: 0.227584
# [1850]	valid_0's rce: 22.9909	valid_0's prauc: 0.341306	valid_1's rce: 15.5042	valid_1's prauc: 0.227585
# [1875]	valid_0's rce: 22.9911	valid_0's prauc: 0.341309	valid_1's rce: 15.5042	valid_1's prauc: 0.227585
# [1900]	valid_0's rce: 22.9913	valid_0's prauc: 0.341312	valid_1's rce: 15.5042	valid_1's prauc: 0.227586
# [1925]	valid_0's rce: 22.9916	valid_0's prauc: 0.341316	valid_1's rce: 15.5043	valid_1's prauc: 0.227586
# [1950]	valid_0's rce: 22.9917	valid_0's prauc: 0.34132	valid_1's rce: 15.5043	valid_1's prauc: 0.227586
# [1975]	valid_0's rce: 22.9919	valid_0's prauc: 0.341323	valid_1's rce: 15.5043	valid_1's prauc: 0.227587
# [2000]	valid_0's rce: 22.992	valid_0's prauc: 0.341325	valid_1's rce: 15.5043	valid_1's prauc: 0.227587
# [2025]	valid_0's rce: 22.9921	valid_0's prauc: 0.34133	valid_1's rce: 15.5043	valid_1's prauc: 0.227587
# [2050]	valid_0's rce: 22.9923	valid_0's prauc: 0.341332	valid_1's rce: 15.5043	valid_1's prauc: 0.227587
# [2075]	valid_0's rce: 22.9924	valid_0's prauc: 0.341333	valid_1's rce: 15.5043	valid_1's prauc: 0.227587
# [2100]	valid_0's rce: 22.9924	valid_0's prauc: 0.341335	valid_1's rce: 15.5044	valid_1's prauc: 0.227587
# [2125]	valid_0's rce: 22.9925	valid_0's prauc: 0.341337	valid_1's rce: 15.5044	valid_1's prauc: 0.227587
# [2150]	valid_0's rce: 22.9926	valid_0's prauc: 0.341338	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2175]	valid_0's rce: 22.9927	valid_0's prauc: 0.34134	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2200]	valid_0's rce: 22.9927	valid_0's prauc: 0.341341	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2225]	valid_0's rce: 22.9928	valid_0's prauc: 0.341342	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2250]	valid_0's rce: 22.9929	valid_0's prauc: 0.341343	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2275]	valid_0's rce: 22.9929	valid_0's prauc: 0.341344	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2300]	valid_0's rce: 22.993	valid_0's prauc: 0.341345	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2325]	valid_0's rce: 22.993	valid_0's prauc: 0.341345	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2350]	valid_0's rce: 22.993	valid_0's prauc: 0.341345	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2375]	valid_0's rce: 22.9931	valid_0's prauc: 0.341346	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2400]	valid_0's rce: 22.9931	valid_0's prauc: 0.341347	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2425]	valid_0's rce: 22.9931	valid_0's prauc: 0.341347	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2450]	valid_0's rce: 22.9931	valid_0's prauc: 0.341348	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2475]	valid_0's rce: 22.9932	valid_0's prauc: 0.341348	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2500]	valid_0's rce: 22.9932	valid_0's prauc: 0.341348	valid_1's rce: 15.5044	valid_1's prauc: 0.227588
# [2525]	valid_0's rce: 22.9932	valid_0's prauc: 0.341348	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2550]	valid_0's rce: 22.9932	valid_0's prauc: 0.341349	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2575]	valid_0's rce: 22.9932	valid_0's prauc: 0.341349	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2600]	valid_0's rce: 22.9932	valid_0's prauc: 0.341349	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2625]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2650]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2675]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2700]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2725]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2750]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2775]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2800]	valid_0's rce: 22.9933	valid_0's prauc: 0.34135	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2825]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2850]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2875]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2900]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2925]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2950]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [2975]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3000]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3025]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3050]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3075]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3100]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3125]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3150]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3175]	valid_0's rce: 22.9933	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3200]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3225]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3250]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3275]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3300]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3325]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3350]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3375]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3400]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3425]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3450]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3475]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3500]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3525]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3550]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3575]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3600]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3625]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3650]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3675]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3700]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3725]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3750]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3775]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3800]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3825]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3850]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3875]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3900]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3925]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3950]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [3975]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4000]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4025]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4050]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4075]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4100]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4125]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4150]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4175]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4200]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4225]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4250]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4275]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4300]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4325]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4350]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4375]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4400]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4425]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4450]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4475]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4500]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4525]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4550]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4575]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4625]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4650]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4675]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4700]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4725]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4750]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4775]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4800]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4825]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4850]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4875]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4900]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4925]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4950]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [4975]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# [5000]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# Did not meet early stopping. Best iteration is:
# [5000]	valid_0's rce: 22.9934	valid_0's prauc: 0.341351	valid_1's rce: 15.5044	valid_1's prauc: 0.227589
# Evaluated only: rce
#
#
# reply
# ==================================================
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.164858 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 27634
# [LightGBM] [Info] Number of data points in the train set: 3607787, number of used features: 55
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.040417 -> initscore = -3.167248
# [LightGBM] [Info] Start training from score -3.167248
# Training until validation scores don't improve for 50 rounds
# [25]	valid_0's rce: 23.9521	valid_0's prauc: 0.271079	valid_1's rce: 21.0282	valid_1's prauc: 0.227644
# [50]	valid_0's rce: 26.8691	valid_0's prauc: 0.305226	valid_1's rce: 22.0233	valid_1's prauc: 0.231931
# [75]	valid_0's rce: 27.9082	valid_0's prauc: 0.324373	valid_1's rce: 22.1921	valid_1's prauc: 0.233187
# [100]	valid_0's rce: 28.5228	valid_0's prauc: 0.335268	valid_1's rce: 22.2513	valid_1's prauc: 0.233723
# [125]	valid_0's rce: 29.0392	valid_0's prauc: 0.344271	valid_1's rce: 22.2988	valid_1's prauc: 0.234125
# [150]	valid_0's rce: 29.4477	valid_0's prauc: 0.351391	valid_1's rce: 22.3208	valid_1's prauc: 0.234343
# [175]	valid_0's rce: 29.7873	valid_0's prauc: 0.35746	valid_1's rce: 22.3277	valid_1's prauc: 0.234441
# [200]	valid_0's rce: 30.085	valid_0's prauc: 0.362965	valid_1's rce: 22.3377	valid_1's prauc: 0.234563
# [225]	valid_0's rce: 30.3606	valid_0's prauc: 0.368078	valid_1's rce: 22.3457	valid_1's prauc: 0.234665
# [250]	valid_0's rce: 30.592	valid_0's prauc: 0.37235	valid_1's rce: 22.3534	valid_1's prauc: 0.234882
# [275]	valid_0's rce: 30.8047	valid_0's prauc: 0.37627	valid_1's rce: 22.3596	valid_1's prauc: 0.23509
# [300]	valid_0's rce: 30.9771	valid_0's prauc: 0.379379	valid_1's rce: 22.3615	valid_1's prauc: 0.235199
# [325]	valid_0's rce: 31.1387	valid_0's prauc: 0.382708	valid_1's rce: 22.3559	valid_1's prauc: 0.235236
# Early stopping, best iteration is:
# [288]	valid_0's rce: 30.9019	valid_0's prauc: 0.377912	valid_1's rce: 22.3636	valid_1's prauc: 0.23521
# Evaluated only: rce
#
#
# quote
# ==================================================
# [LightGBM] [Info] [cross_entropy:Init]: (objective) labels passed interval [0, 1] check
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.173341 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 27892
# [LightGBM] [Info] Number of data points in the train set: 3607787, number of used features: 56
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/miniconda/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] [cross_entropy:BoostFromScore]: pavg = 0.005906 -> initscore = -5.125938
# [LightGBM] [Info] Start training from score -5.125938
# Training until validation scores don't improve for 50 rounds
# [25]	valid_0's rce: 20.3439	valid_0's prauc: 0.120078	valid_1's rce: 10.9927	valid_1's prauc: 0.0394301
# [50]	valid_0's rce: 25.7529	valid_0's prauc: 0.217297	valid_1's rce: 11.4828	valid_1's prauc: 0.0461653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's rce: 28.6081	valid_0's prauc: 0.271621	valid_1's rce: 11.5227	valid_1's prauc: 0.0503475
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's rce: 31.009	valid_0's prauc: 0.319886	valid_1's rce: 11.6446	valid_1's prauc: 0.0551512
# [125]	valid_0's rce: 33.0065	valid_0's prauc: 0.359886	valid_1's rce: 11.6633	valid_1's prauc: 0.0588586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's rce: 34.8962	valid_0's prauc: 0.396397	valid_1's rce: 11.7647	valid_1's prauc: 0.062892
# [175]	valid_0's rce: 36.3715	valid_0's prauc: 0.423336	valid_1's rce: 11.8164	valid_1's prauc: 0.0660597
# [200]	valid_0's rce: 37.8117	valid_0's prauc: 0.448828	valid_1's rce: 11.8527	valid_1's prauc: 0.0687458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's rce: 38.943	valid_0's prauc: 0.467511	valid_1's rce: 11.8848	valid_1's prauc: 0.0708346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's rce: 40.0537	valid_0's prauc: 0.487015	valid_1's rce: 11.9015	valid_1's prauc: 0.0730367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's rce: 40.8896	valid_0's prauc: 0.502731	valid_1's rce: 11.9155	valid_1's prauc: 0.0750191
# [300]	valid_0's rce: 41.7277	valid_0's prauc: 0.517588	valid_1's rce: 11.9239	valid_1's prauc: 0.0766505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's rce: 42.4651	valid_0's prauc: 0.530214	valid_1's rce: 11.943	valid_1's prauc: 0.0778893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's rce: 43.0954	valid_0's prauc: 0.540548	valid_1's rce: 11.948	valid_1's prauc: 0.0790353
# [375]	valid_0's rce: 43.6154	valid_0's prauc: 0.548739	valid_1's rce: 11.9597	valid_1's prauc: 0.0801501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's rce: 44.0873	valid_0's prauc: 0.556353	valid_1's rce: 11.9543	valid_1's prauc: 0.0809922
# [425]	valid_0's rce: 44.5453	valid_0's prauc: 0.563033	valid_1's rce: 11.9455	valid_1's prauc: 0.0819835
# Early stopping, best iteration is:
# [376]	valid_0's rce: 43.6432	valid_0's prauc: 0.549321	valid_1's rce: 11.9634	valid_1's prauc: 0.0801798
# Evaluated only: rce
#
#
# CPU times: user 12h 32min 33s, sys: 2min 49s, total: 12h 35min 23s
# Wall time: 3h 44min 25s

# %%
from matplotlib import pyplot as plt
fig, axs = plt.subplots(2, 4, figsize=(20,8))
axs = axs.flatten()
for idx, title in enumerate(['like', 'retweet', 'reply', 'quote']):
    lgb.plot_metric(boosters[idx][1], 'prauc', ax=axs[idx])
    axs[idx].set_title(title+'-PRAUC')
    lgb.plot_metric(boosters[idx][1], 'rce', ax=axs[idx+4])
    axs[idx+4].set_title(title+'-RCE')
plt.tight_layout()
plt.savefig('fig_learning_curves_QQQ.png')
plt.show()

# %%
from matplotlib import pyplot as plt

# 1 vertical
# -1 horizontal
mode = 1 # -1  

_, axs = plt.subplots(2,2,figsize=(25,20))
axs = axs.flatten()
for i, target in enumerate(['like', 'retweet', 'reply', 'quote']):
    bst = lgb.Booster(model_file='submissions/zzz_final2/' + target + '_bst_cs.lgb')
    fn, im = zip(*sorted(list(zip(bst.feature_name(), bst.feature_importance('gain'))), key=lambda x: mode*x[1]))
#     print(bst.__dict__['params'])
    ax = axs[i]
    if mode == 1:
        ax.barh(fn, im)
    else:
        ax.bar(fn, im)
        ax.set_xticklabels(fn, rotation=90)
    
    ax.set_title(target);
plt.tight_layout()
# plt.savefig('fig_feature_importance_QQQ.png')
plt.show()

# %%
# Copy all the necessary files into the RecsysDocker

# !cp *.lgb /data/recsys/RecsysDocker/
# !cp /data/recsys/auth_pop_tweet/auth_merge_div_counts.csv /data/recsys/RecsysDocker/
# !cp /data/recsys/tef_read_tt/read_tt_merge_div.csv /data/recsys/RecsysDocker/
# !cp /data/recsys/tef_auth_tt/auth_tt_merge_div.csv /data/recsys/RecsysDocker/
# !cp /data/recsys/read_pop/read_merge_div_counts.csv /data/recsys/RecsysDocker/
# !cp means.json /data/recsys/RecsysDocker/
